# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pymongo
import pprint

# %%
course_cluster_uri = 'mongodb://admin:1Pfhr39Hdi4@ds119060.mlab.com:19060/pat_doc_recipedb'

# %%
course_client = pymongo.MongoClient(course_cluster_uri)
recipes = course_client['pat_doc_recipedb']['recipes']

# %%
query = {
    "upvotes": {"$exists": True}
}

projection = {
    "upvotes" : 1,
    "recipe_name": 1,
    '_id': 0
}

# %%
rm = list(recipes.find(query, projection))

# %%
pprint.pprint(rm[0])
# Out:
# {'recipe_name': 'Pats Curry', 'upvotes': 2}

# %%
upvotes = [recipe['upvotes'] for recipe in rm]

# %%
print(upvotes)
# Out:
# [2, 4, 4, 2, 2, 2, 2, 1]

# %%
recipe_names = [recipe["recipe_name"] for recipe in rm]

# %%
print (recipe_names)
# Out:
# ['Pats Curry', 'Chicken Tikka Masala', 'Souvlakia', 'Irish fish chowder with soda bread', 'Sizzling steak fajitas', 'Comforting cottage pie', 'Chicken jalfrezi', 'Jerk pork with sweet potato mash and salsa']

# %%
plt.clf()
fig, ax = plt.subplots()
ax.bar(recipe_names, upvotes, alpha=0.5)

plt.title("UpVotes per Recipe")
plt.xlabel('Recipe Names')
plt.ylabel("UpVotes")

plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>
